# %%
""" It is the final Women’s volleyball championship game in 2020. The competition takes place in the USA. 
Teams are here for the gold medallion. Burcu is one of the players who is a current student at Hult 
International Business School in the boston campus. You are going to be a couch of one of the team. As a coach, 
you will guide the team to win by giving directions during the match. In this game, we have the best players 
from the 2019 Volleyball World Cup championship into two teams. As a coach, you have already given 
all player’s best role in the position and also their weaknesses. Let’s play the game."""

#import functions

import time
import datetime
import sys
import random
import re

#Global variables

player_1        = ''
team_input      = ''
player_team     = ''
team_score      = 0
teammate_1      = ''
teammate_2      = ''
opponent        = ''
Boston_score    = 0
gameover        = ''    
christmas_gift  = ''    

##############################################################################
####################### DEFINITION SECTION ####################################
##############################################################################

def commentator_speech(comment):
    """The comments will be printed slowly in this function"""
    for letter in comment:
        print(letter, end = '')
        time.sleep(0.04)


def decoration():
    """ To divide the text two lines of # is used."""
    
    print("""\n
##############################################################################
##############################################################################
\n""")
    
#Definition of the fail
    
def fail():
    global sys
    global gameover

    """To end the game and after that send the user to the team_selection part this function is used."""

    print(f"""\n\n Thank you for playing the final Women’s volleyball championship game in 2020{player_1}.! The game has now ended. if you would like to try again, both teams would so much appreciate it! The game ended at the three sets and {player_team}'s score was {team_score}\n\n""")
    gameover = input(prompt = '\nDo you want to play again? Y/N\n').lower().strip()
    if gameover == 'y'or gameover == 'yes': 
        input('\n <Press "Y" to begin again>\n')
        start()

    else:
        sys.exit()
            
##############################################################################
############################### BEGIN ########################################
##############################################################################

def start():
    #Building the global variable of the player
    #Random is used in this function
    
    global player_1
    
    random_welcome = random.randint(1, 3)
    
    #To write their name user(player_1) can only type letter 
    
    while len(player_1) <= 0 or len(re.findall(r'\d', player_1))>0:
            player_1 = input('\n\nWho is going to be a coach of the volleyball team?🏐"\n').capitalize().strip()

    #Making the commentator cheers and says player_1
    player_upper = player_1.upper()
    
    if random_welcome == 1:
        print(f"""\nWelcome to the final Women’s volleyball championship {player_1}🙋‍♀️! As a couch you need to know exactly what your team's \nneeds at any given moments during the competition.""")
    
    elif random_welcome == 2:
              print(f"""\nHello {player_1}🙋‍♀️!!!The final Women’s volleyball championship game has been waiting for you.\n""")
            
    else:
        print(f"""\nWelcome {player_1}🙋‍♀️!!! The final Women’s volleyball championship game has been waiting for you. You will have an \nunforgettable moment by playing this game today.\n""")

    input('\n <Press Enter to Continue>\n')
    

    ##############################################################################
    ############################# TEAM SELECTION #################################
    ##############################################################################

    #Using global variable team_input
    #creating the Conditional Statement with team names 


    def team_selection():
        global team_input
        global player_team

        """ This function allows users to come back to this point to play again and choose another team"""
        while team_input not in ['hult boston', 'hult san francisco']:
            response = input("""\n Which team would you like to play with?\n
            Hult Boston or Hult San Francisco \n""").lower()

            if response == 'hult boston': 
                print('\n Excellent choice!\n')
                team_input = response
                player_team = 'Hult Boston'

            elif response == 'hult san francisco':
                print('\n Nice!\n')
                team_input = response
                player_team = 'Hult San Francisco'
            else:
                print(team_input)
                print("""\n That team is not recognized as part of this version! Please type either 'Hult Boston' or 'Hult San Francisco'.\n""")

    #The user chooses a team in this function
    team_selection()

    input('\n <Press Enter to BEGIN>\n')
    
##############################################################################
############################ COMMENTARY WELCOME ##############################
##############################################################################
    

    #Dynamic text is created by using 'datetime' in 'Good morning/afternoon/evening' message 
    currenttime = datetime.datetime.now()

    #To create the text slowly 'commentator_speech' function utilizes 

    print("""\n
        #######################
        ###### COMMENTARY:######
        #######################\n""")   
    
    if currenttime.hour < 12:
        print('COMMENTATOR:', end = '')
        commentator_speech(' Good morning!🌅 ')

    elif 12 <= currenttime.hour < 18:
        print('COMMENTATOR:', end = '')
        commentator_speech(' Good afternoon!🌞 ')

    else:
        print('COMMENTATOR:', end = '')
        commentator_speech(' Good evening!🌙')

    commentator_speech(f"""We are so excited for having you in this game. We know every rules but we need you to \nmake tactical decisions for us during the game.You are a game changer {player_1}✨!The great news is one of your student \nBurcu from Boston campus is a player as well.!!!!She needs your help to go back with highly motivated to the \nschool and finish her Python assignment. This game is the final one and it is going to be very debatable. Both team's fans are so excited.There is no time to waste {player_1}. Let's begin...""")


    input('\n <Press Enter to Continue>\n')

    ##############################################################################
    ################################# TOP PLAYERS ###############################
    ##############################################################################
    print("""
    ##############################################################################
    ################################ TOP PLAYERS ###############################
    ##############################################################################
    """)

    #Give the information about top four players in the game with their strengths and weaknesses
    #Create dictionary with the best players in both team
    teams = {
        'Hult Boston': [' Hult Boston Best Players\n ',
            '1. Burcu Oskay; She is the best opposite hitter. But she is not a good passer.\n',
            '2. Cristina Chirichella; She is the top blocker of the competitions.But she is not a good attacker.\n'
        ], 
        'Hult San Francisco': ['Hult San Francisco Best Player\n',
            '1. Zhu Ting; she is the best outside hitter. But she is not a good blocker.\n', 
            '2. Annie Drews; she is the best libero. But she is not a good hitter.\n'
        ]
    }
    #print function uses for the team_members
    for team_members in teams[player_team]:
        print(team_members)

    input('\n <Press Enter to Continue>\n')    
    decoration()

    #This function shows conditional Statement for the chosen player_team     

    if player_team == "Hult Boston":
        print(""" \n Hult Boston Best Player\n
    1. Burcu Oskay; She is the best opposite hitter. But she is not a good passer.\n
    2. Cristina Chirichella; She is the top blocker of the competitions.But she is not a good attacker.\n""")

    elif player_team == "Hult San Francisco":  
        print(""" \n
    Hult SF Best Players\n
    1. Zhu Ting; she is the best outside hitter. But she is not a good blocker.\n
    2. Annie Drews; she is the best libero. But she is not a good hitter.\n""")

    ('\n <Press Enter to Continue>\n')

    ##############################################################################
    ############################## PLAYER INSTRUCTIONS ###########################
    ##############################################################################

    print("""\n\t\t\t
    #######################
    #PLAYING INSTRUCTIONS:#
    #######################\n
    In order to control your player in scheme, select either 'a' or 'b'\n""")
    decoration()

    input('\n <Press Enter to Continue>\n')

    #Giving start to game

    commentator_speech(f"""LAUNCH:  Here we go, Start the game! People can not learn without lose.But today both teams are here to win.""")

    decoration()
    
    
    #Adding global variable to keep score
    team_score = 0

    ##############################################################################
    ################################# LEVEL 1 ####################################
    ##############################################################################
    
    #COMMENTATOR Details before the first debate
    def level_1():
        """Player_1 will make her/his first decision in stage."""
        #Adding score to global variable
        global team_score
        
        
        print("""\n
        #######################
        ######DEBATE 1:######
        #######################\n""")
        
        #COMMENTATOR Details for the first debate
        print('\nCOMMENTATOR:', end = '')
        commentator_speech(f""" As we expected, {player_team} have faced a big challenge. It is time to give some tactics {player_1}.""")


        #Player_1 determine his/her first decision for the debate
        print('\nMINUTE 30:', end = '')
        commentator_speech(f""" CHANCE! Cristina passed the ball to Burcu! It is time to hit the score up. What will happen??! \n

            Should your player:

            [a] hit the ball opposite to a teammate
            [b] Pass to other team""")

        answer_1 = ""

        while answer_1 not in ['a', 'b']:
            response = input('\n').lower()

            if response == 'a': 
                print( f'''COMMENTATOR:''')
                commentator_speech(f'''AND {player_team} SCOOORES😊😊!! Amazing TACTIC {player_1}!!!''')
                team_score += 1
                answer_1 = response


            elif response == 'b':
                print(f' COMMENTATOR:') 
                commentator_speech(f'''OH NO😟! Horrible decision {player_1}! Hope to {player_team} get a change again!''')
                answer_1 = response


            else:
                print(f''' COMMENTATOR:''')
                commentator_speech(f"""Unavailable action by {player_1} . Please type
                either 'a' or 'b'. Please try again!""")

        input('\n <Press Enter to Continue>\n')
        decoration()
        
        
    level_1() #Calling level 1

        ##############################################################################
        ################################# LEVEL 2 ####################################
        ##############################################################################
        
        #COMMENTATOR Details for the second debate

    def level_2():
        """This function is the second decision level."""  

        #Adding score to global variable
        global team_score

        print("""\n\t\t\t
        #######################
        ######SET 2:######
        #######################\n""")

        #print function for the commentator speech
        print('\nCOMMENTATOR:', end = '')
        commentator_speech(f""" This is the most debatable game in 2020. Even if Corona didn't stress me out that much. No, l'm \nkidding. You are making decisions wisely {player_1}. Do you think {player_team} win the game! Let's see.\n""")

        #player_1 makes her/his second decision for the debate   
        print('\nSET 2:', end = '')
        commentator_speech(f""" Your team has just missed the chance! That was a terrible shout.Now the opposing team has a chance.\nNo worries. It is hard to predict from now. \n

            Should your team player serve the ball to the left or right corner of your rival team's ground?

            [a] Left
            [b] Right""")

        answer_2 = ""

        while answer_2 not in ['a', 'b']:
            response = input('\n').lower()

            if response == 'a': 
                print( 'COMMENTATOR:')
                commentator_speech(f'''Na Na Na💥! The blocker returned the ball. This was not the good idea {player_1}!''')
                answer_2 = response

            elif response == 'b':
                print('COMMENTATOR:') 
                commentator_speech(f'''Wonderful serve by your player! This could really win set of the year!''')
                team_score += 1
                answer_2 = response

            else:
                print('COMMENTATOR:')
                commentator_speech(f"""Unavailable action by {player_1} . Please type either 'a' or 'b'. Please try again!""")

        input('\n <Press Enter to Continue>\n')
        decoration()

    level_2() #Calling Level 2 

    ##############################################################################
    ################################# LEVEL 3 ####################################
    ##############################################################################    

    #COMMENTATOR Details for the third debate

    def level_3():
        """This is the last level of the game."""
        
        #User can change the variables that has being added before in this function
        global team_score
        global teammate_1
        global teammate_2
        global opponent

        print("""\n\t\t\t
        #######################
        ######SET 3:######
        #######################\n""")

        #COMMENTATOR Introduction to the third attacking scenario
        print('\nCOMMENTATOR:', end = '')
        commentator_speech(f""" Hey Everybody. We are watching the best debatable games today. Let's give a big applaud to the \nboth teams!\n""")
        
        #Before making last decision, this function display which player is debating whom
        if player_team == 'Hult Boston':
            teammate_1 = 'Burcu'
            teammate_2 = 'Christina'
            opponent = 'Hult San Francisco'

        elif player_team == 'Hult San Francisco':
            teammate_1 = 'Zui'
            teammate_2 = 'Annie'
            opponent = 'Hult Boston'
            
        #The last decision before hit the score by player_1    
        print('\nSET 3:', end = '')
        commentator_speech(f""" {teammate_2} is serving the ball towards {opponent}\'s side. One of the player from {opponent} passed the ball to {teammate_1}. {teammate_1} has only chance to win the game.\n
    
            What should {teammate_1} do?

            [a] Hit the opposite toward {opponent}
            [b] Pass it to teammate!!""")

        answer_3 = ""

        while answer_3 not in ['a', 'b']:
            response = input('\n').lower()

    #Nested Conditional Statement
            if response == 'a': 
                    # Burcu is from Turkey and gave a gold madellion to her team in her country. 
                    if teammate_1 == 'Burcu':
                        print( '\nCOMMENTATOR:')
                        commentator_speech(f'''Wise decision by {player_1}! Burcu is the best opposite hitter!! She hit the ball opposite and SCORESSS!!! Everyone is \ncheeringgg!!''')
                        team_score += 1
                        answer_3 = response
                    #Zui is from China. She gave a silver madellion to her team in her country.    
                    elif teammate_1 == 'Zui':
                        print( 'COMMENTATOR:')
                        commentator_speech(f'''What a bad decision! Zui is not a good blocker to catch the ball. The team lost another great chance''')
                        answer_3 = response
                        fail()

            elif response == 'b':
                print('\nCOMMENTATOR:') 
                commentator_speech(f'''l am sorry {player_1}. You failed. You need to know your players' best positions in the game. Volleyball is a tactical game as well.''')
                answer_3 = response
                fail()

            else:
                print('\nCOMMENTATOR:')
                commentator_speech(f"""Unavailable action by {player_1}.Please type either 'a' or 'b'. Please try again!""")

            input('\n <Press Enter to Continue>\n')
            decoration()
            

    level_3() #Calling Level 3
    

##############################################################################
######################### CHRISTMAS GIFT SEASON ##############################
##############################################################################
       
   
    def christmas_gift():
        """This function initiates a secret ending."""

        #Adding global variables
        global team_score

        #This is the christmas gift for the winner
        while team_score > 0:
            if player_team == 'Hult San Francisco':
                print("""\n\t\t\t
                #######################
                ##CHRISTMAS GIFT SEASON ENDING:###
                #######################\n\n""")
                print("\nCOMMENTATOR:", end = '')
                Boston_score = 3
                commentator_speech(f""" Ladies and Gentleman. We are having a spectacular moment today!! A comeback by Hult Boston! Definitely the best team in the world! Burcu just scored {Boston_score} at the last set!!! The game ends! Hult Boston {Boston_Score} and Hult San Francisco {team_score}. What an incredible night!""")
                fail()

            #This is the ordinary ending
            else:
                print("""\n\t\t\t
                #######################
                ##########END:#########
                #######################\n""")
                print('\nCOMMENTATOR:')
                commentator_speech(f"""Final whistle! We saw that the loser team is congratulating the players of Hult Boston Campus.\nThank you for being with us today.\nWe hope to see you next time""")
                print("Please play again. Choose another team and try to find the secret ending!")

                gameover = input(prompt = 'Do you want to play again? Y/N').lower().strip()
                if gameover == 'y' or gameover == 'yes' or gameover =='Y': 
                    start()

                else:
                    fail()

    christmas_gift() #Calling Christmas Gift Season
    
    
start()
